# %% [markdown]
# # Joins | CO2 Emissions Meets Democracy Meets World💥💥
#
# #### This file joins the CO2 Emissions to the Democracy Index Data.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import Data

# %%
democracy = pd.read_csv('clean_democracy_data.csv', index_col=0)
emissions = pd.read_csv('clean_emissions.csv', index_col=0)
world = pd.read_csv('clean_world.csv', index_col=0)
country_metadata = pd.read_csv('clean_country_metadata.csv', index_col=0)

# %% [markdown]
# ## View Data

# %%
democracy
# Out:
#       geo         name        time  Democracy index (EIU)
# 0     AFG  Afghanistan  2006-01-01                   30.6
# 1     AFG  Afghanistan  2007-01-01                   30.4
# 2     AFG  Afghanistan  2008-01-01                   30.2
# 3     AFG  Afghanistan  2009-01-01                   27.5
# 4     AFG  Afghanistan  2010-01-01                   24.8
# ...   ...          ...         ...                    ...
# 2496  ZWE     Zimbabwe  2016-01-01                   30.5
# 2497  ZWE     Zimbabwe  2017-01-01                   31.6
# 2498  ZWE     Zimbabwe  2018-01-01                   31.6
# 2499  ZWE     Zimbabwe  2019-01-01                   31.6
# 2500  ZWE     Zimbabwe  2020-01-01                   31.6
#
# [2501 rows x 4 columns]

# %%
emissions
# Out:
#       Country Name Country Code        Year  \
# 2      Afghanistan          AFG  1960-01-01
# 267    Afghanistan          AFG  1961-01-01
# 532    Afghanistan          AFG  1962-01-01
# 797    Afghanistan          AFG  1963-01-01
# 1062   Afghanistan          AFG  1964-01-01
# ...            ...          ...         ...
# 14574     Zimbabwe          ZWE  2014-01-01
# 14839     Zimbabwe          ZWE  2015-01-01
# 15104     Zimbabwe          ZWE  2016-01-01
# 15369     Zimbabwe          ZWE  2017-01-01
# 15634     Zimbabwe          ZWE  2018-01-01
#
#        CO2 emissions (metric tons per capita)
# 2                                    0.046057
# 267                                  0.053589
# 532                                  0.073721
# 797                                  0.074161
# 1062                                 0.086174
# ...                                       ...
# 14574                                0.894256
# 14839                                0.897598
# 15104                                0.783303
# 15369                                0.718570
# 15634                                0.849793
#
# [15635 rows x 4 columns]

# %%
world
# Out:
#       Country Name Country Code        Year  \
# 0      Afghanistan          AFG  1960-01-01
# 1      Afghanistan          AFG  1961-01-01
# 2      Afghanistan          AFG  1962-01-01
# 3      Afghanistan          AFG  1963-01-01
# 4      Afghanistan          AFG  1964-01-01
# ...            ...          ...         ...
# 16221     Zimbabwe          ZWE  2016-01-01
# 16222     Zimbabwe          ZWE  2017-01-01
# 16223     Zimbabwe          ZWE  2018-01-01
# 16224     Zimbabwe          ZWE  2019-01-01
# 16225     Zimbabwe          ZWE  2020-01-01
#
#        Compulsory education, duration (years)  GDP (current US$)  \
# 0                                         NaN       5.377778e+08
# 1                                         NaN       5.488889e+08
# 2                                         NaN       5.466667e+08
# 3                                         NaN       7.511112e+08
# 4                                         NaN       8.000000e+08
# ...                                       ...                ...
# 16221                                     7.0       2.054868e+10
# 16222                                     7.0       1.901533e+10
# 16223                                     7.0       1.952362e+10
# 16224                                     7.0       1.693243e+10
# 16225                                     7.0       1.676851e+10
#
#        GDP per capita (current US$)  GDP per capita growth (annual %)
# 0                         59.773234                               NaN
# 1                         59.860900                               NaN
# 2                         58.458009                               NaN
# 3                         78.706429                               NaN
# 4                         82.095307                               NaN
# ...                             ...                               ...
# 16221                   1464.588957                         -0.793105
# 16222                   1335.665064                          3.182506
# 16223                   1352.162653                          2.047700
# 16224                   1156.154864                         -9.396793
# 16225                   1128.210711                         -9.346018
#
# [16226 rows x 7 columns]

# %%
country_metadata
# Out:
#     Country Code                  Name      Capital City     Area Km2  \
# 0            AND               Andorra  Andorra la Vella        468.0
# 1            ARE  United Arab Emirates         Abu Dhabi     82,880.0
# 2            AFG           Afghanistan             Kabul    647,500.0
# 3            ATG   Antigua and Barbuda        St. John's        443.0
# 4            AIA              Anguilla        The Valley        102.0
# ..           ...                   ...               ...          ...
# 245          YEM                 Yemen             Sanaa    527,970.0
# 246          MYT               Mayotte         Mamoudzou        374.0
# 247          ZAF          South Africa          Pretoria  1,219,912.0
# 248          ZMB                Zambia            Lusaka    752,614.0
# 249          ZWE              Zimbabwe            Harare    390,580.0
#
#      Population Continent Code Continent Name
# 0        77,006             EU         Europe
# 1     9,630,959             AS           Asia
# 2    37,172,386             AS           Asia
# 3        96,286            NaN  North America
# 4        13,254            NaN  North America
# ..          ...            ...            ...
# 245  28,498,687             AS           Asia
# 246     279,471             AF         Africa
# 247  57,779,622             AF         Africa
# 248  17,351,822             AF         Africa
# 249  14,439,018             AF         Africa
#
# [250 rows x 7 columns]

# %% [markdown]
# It happened again, the NA in Continent is not a null..

# %%
country_metadata['Continent Code'] = country_metadata['Continent Code'].fillna(value='NA')

# %% [markdown]
# Checking data types are interoperable.

# %%
emissions.dtypes
# Out:
# Country Name                               object
# Country Code                               object
# Year                                       object
# CO2 emissions (metric tons per capita)    float64
# dtype: object

# %%
democracy.dtypes
# Out:
# geo                       object
# name                      object
# time                      object
# Democracy index (EIU)    float64
# dtype: object

# %%
world.dtypes
# Out:
# Country Name                               object
# Country Code                               object
# Year                                       object
# Compulsory education, duration (years)    float64
# GDP (current US$)                         float64
# GDP per capita (current US$)              float64
# GDP per capita growth (annual %)          float64
# dtype: object

# %%
country_metadata.dtypes
# Out:
# Country Code      object
# Name              object
# Capital City      object
# Area Km2          object
# Population        object
# Continent Code    object
# Continent Name    object
# dtype: object

# %% [markdown]
# We have a lot more years in CO2_Emissions than in democracy_data, but democracy_data has more recent years. We can decide to include them all, joining on country and year, but excluding no year.

# %% [markdown]
# ## Join - Emissions + Democracy
# A left join on either will exclude years from either columns, and as we're not sure what data to keep or get rid of as of yet, we'll keep it all. So an outer join is beneficial.

# %%
democracy_emissions = pd.merge(emissions, democracy,  how='outer', left_on=['Country Code','Year'], right_on = ['geo','time'])

# %%
democracy_emissions
# Looks good.
# Out:
#       Country Name Country Code        Year  \
# 0      Afghanistan          AFG  1960-01-01
# 1      Afghanistan          AFG  1961-01-01
# 2      Afghanistan          AFG  1962-01-01
# 3      Afghanistan          AFG  1963-01-01
# 4      Afghanistan          AFG  1964-01-01
# ...            ...          ...         ...
# 15973          NaN          NaN         NaN
# 15974          NaN          NaN         NaN
# 15975          NaN          NaN         NaN
# 15976          NaN          NaN         NaN
# 15977          NaN          NaN         NaN
#
#        CO2 emissions (metric tons per capita)  geo      name        time  \
# 0                                    0.046057  NaN       NaN         NaN
# 1                                    0.053589  NaN       NaN         NaN
# 2                                    0.073721  NaN       NaN         NaN
# 3                                    0.074161  NaN       NaN         NaN
# 4                                    0.086174  NaN       NaN         NaN
# ...                                       ...  ...       ...         ...
# 15973                                     NaN  YEM     Yemen  2020-01-01
# 15974                                     NaN  ZMB    Zambia  2019-01-01
# 15975                                     NaN  ZMB    Zambia  2020-01-01
# 15976                                     NaN  ZWE  Zimbabwe  2019-01-01
# 15977                                     NaN  ZWE  Zimbabwe  2020-01-01
#
#        Democracy index (EIU)
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 15973                   19.5
# 15974                   50.9
# 15975                   48.6
# 15976                   31.6
# 15977                   31.6
#
# [15978 rows x 8 columns]

# %% [markdown]
# ## More cleaning. 🧹
#
# We don't need repetitive columns but we can't drop them before we've transferred the unique data over to the other attributes.

# %%
# If Country Code 'null' then take the data from 'geo' in the same row.
democracy_emissions['Country Name'].fillna(democracy_emissions['name'], inplace=True)
democracy_emissions['Country Code'].fillna(democracy_emissions['geo'], inplace=True)
democracy_emissions['Year'].fillna(democracy_emissions['time'], inplace=True)

# %%
democracy_emissions #Checking it worked.
# Out:
#       Country Name Country Code        Year  \
# 0      Afghanistan          AFG  1960-01-01
# 1      Afghanistan          AFG  1961-01-01
# 2      Afghanistan          AFG  1962-01-01
# 3      Afghanistan          AFG  1963-01-01
# 4      Afghanistan          AFG  1964-01-01
# ...            ...          ...         ...
# 15973        Yemen          YEM  2020-01-01
# 15974       Zambia          ZMB  2019-01-01
# 15975       Zambia          ZMB  2020-01-01
# 15976     Zimbabwe          ZWE  2019-01-01
# 15977     Zimbabwe          ZWE  2020-01-01
#
#        CO2 emissions (metric tons per capita)  geo      name        time  \
# 0                                    0.046057  NaN       NaN         NaN
# 1                                    0.053589  NaN       NaN         NaN
# 2                                    0.073721  NaN       NaN         NaN
# 3                                    0.074161  NaN       NaN         NaN
# 4                                    0.086174  NaN       NaN         NaN
# ...                                       ...  ...       ...         ...
# 15973                                     NaN  YEM     Yemen  2020-01-01
# 15974                                     NaN  ZMB    Zambia  2019-01-01
# 15975                                     NaN  ZMB    Zambia  2020-01-01
# 15976                                     NaN  ZWE  Zimbabwe  2019-01-01
# 15977                                     NaN  ZWE  Zimbabwe  2020-01-01
#
#        Democracy index (EIU)
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 15973                   19.5
# 15974                   50.9
# 15975                   48.6
# 15976                   31.6
# 15977                   31.6
#
# [15978 rows x 8 columns]

# %%
# Dropping the attributes.
democracy_emissions = democracy_emissions.drop(columns=['geo', 'name', 'time'])
democracy_emissions #Checking it worked.
# Out:
#       Country Name Country Code        Year  \
# 0      Afghanistan          AFG  1960-01-01
# 1      Afghanistan          AFG  1961-01-01
# 2      Afghanistan          AFG  1962-01-01
# 3      Afghanistan          AFG  1963-01-01
# 4      Afghanistan          AFG  1964-01-01
# ...            ...          ...         ...
# 15973        Yemen          YEM  2020-01-01
# 15974       Zambia          ZMB  2019-01-01
# 15975       Zambia          ZMB  2020-01-01
# 15976     Zimbabwe          ZWE  2019-01-01
# 15977     Zimbabwe          ZWE  2020-01-01
#
#        CO2 emissions (metric tons per capita)  Democracy index (EIU)
# 0                                    0.046057                    NaN
# 1                                    0.053589                    NaN
# 2                                    0.073721                    NaN
# 3                                    0.074161                    NaN
# 4                                    0.086174                    NaN
# ...                                       ...                    ...
# 15973                                     NaN                   19.5
# 15974                                     NaN                   50.9
# 15975                                     NaN                   48.6
# 15976                                     NaN                   31.6
# 15977                                     NaN                   31.6
#
# [15978 rows x 5 columns]

# %%
# Reordering, as the 2019 and 2020 years are out of place.
democracy_emissions.sort_values(by=['Country Name', 'Year'])
# Out:
#       Country Name Country Code        Year  \
# 0      Afghanistan          AFG  1960-01-01
# 1      Afghanistan          AFG  1961-01-01
# 2      Afghanistan          AFG  1962-01-01
# 3      Afghanistan          AFG  1963-01-01
# 4      Afghanistan          AFG  1964-01-01
# ...            ...          ...         ...
# 15632     Zimbabwe          ZWE  2016-01-01
# 15633     Zimbabwe          ZWE  2017-01-01
# 15634     Zimbabwe          ZWE  2018-01-01
# 15976     Zimbabwe          ZWE  2019-01-01
# 15977     Zimbabwe          ZWE  2020-01-01
#
#        CO2 emissions (metric tons per capita)  Democracy index (EIU)
# 0                                    0.046057                    NaN
# 1                                    0.053589                    NaN
# 2                                    0.073721                    NaN
# 3                                    0.074161                    NaN
# 4                                    0.086174                    NaN
# ...                                       ...                    ...
# 15632                                0.783303                   30.5
# 15633                                0.718570                   31.6
# 15634                                0.849793                   31.6
# 15976                                     NaN                   31.6
# 15977                                     NaN                   31.6
#
# [15978 rows x 5 columns]

# %% [markdown]
# ## Join - Emissions + Democracy
# A left join on either will exclude years from either columns, and as we're not sure what data to keep or get rid of as of yet, we'll keep it all. So an outer join is beneficial.

# %%
world_data_joined = pd.merge(democracy_emissions, world,  how='outer', left_on=['Country Code','Year'], right_on = ['Country Code','Year'])

# %%
world_data_joined # looks correct
# Out:
#       Country Name_x Country Code        Year  \
# 0        Afghanistan          AFG  1960-01-01
# 1        Afghanistan          AFG  1961-01-01
# 2        Afghanistan          AFG  1962-01-01
# 3        Afghanistan          AFG  1963-01-01
# 4        Afghanistan          AFG  1964-01-01
# ...              ...          ...         ...
# 16236            NaN          VUT  2020-01-01
# 16237            NaN          VIR  2019-01-01
# 16238            NaN          VIR  2020-01-01
# 16239            NaN          WLD  2019-01-01
# 16240            NaN          WLD  2020-01-01
#
#        CO2 emissions (metric tons per capita)  Democracy index (EIU)  \
# 0                                    0.046057                    NaN
# 1                                    0.053589                    NaN
# 2                                    0.073721                    NaN
# 3                                    0.074161                    NaN
# 4                                    0.086174                    NaN
# ...                                       ...                    ...
# 16236                                     NaN                    NaN
# 16237                                     NaN                    NaN
# 16238                                     NaN                    NaN
# 16239                                     NaN                    NaN
# 16240                                     NaN                    NaN
#
#               Country Name_y  Compulsory education, duration (years)  \
# 0                Afghanistan                                     NaN
# 1                Afghanistan                                     NaN
# 2                Afghanistan                                     NaN
# 3                Afghanistan                                     NaN
# 4                Afghanistan                                     NaN
# ...                      ...                                     ...
# 16236                Vanuatu                                     NaN
# 16237  Virgin Islands (U.S.)                                     NaN
# 16238  Virgin Islands (U.S.)                                     NaN
# 16239                  World                                    10.0
# 16240                  World                                    10.0
#
#        GDP (current US$)  GDP per capita (current US$)  \
# 0           5.377778e+08                     59.773234
# 1           5.488889e+08                     59.860900
# 2           5.466667e+08                     58.458009
# 3           7.511112e+08                     78.706429
# 4           8.000000e+08                     82.095307
# ...                  ...                           ...
# 16236       8.547936e+08                   2782.984340
# 16237                NaN                           NaN
# 16238                NaN                           NaN
# 16239       8.743671e+13                  11394.861127
# 16240       8.457796e+13                  10909.287046
#
#        GDP per capita growth (annual %)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 16236                        -11.383066
# 16237                               NaN
# 16238                               NaN
# 16239                          1.480856
# 16240                         -4.395210
#
# [16241 rows x 10 columns]

# %% [markdown]
# ## Cleaning, again

# %%
# If Country Name 'null' then take the data from 'Country Name' in the same row.
world_data_joined['Country Name_x'].fillna(world_data_joined['Country Name_y'], inplace=True)
world_data_joined #Checking it worked.
# Out:
#               Country Name_x Country Code        Year  \
# 0                Afghanistan          AFG  1960-01-01
# 1                Afghanistan          AFG  1961-01-01
# 2                Afghanistan          AFG  1962-01-01
# 3                Afghanistan          AFG  1963-01-01
# 4                Afghanistan          AFG  1964-01-01
# ...                      ...          ...         ...
# 16236                Vanuatu          VUT  2020-01-01
# 16237  Virgin Islands (U.S.)          VIR  2019-01-01
# 16238  Virgin Islands (U.S.)          VIR  2020-01-01
# 16239                  World          WLD  2019-01-01
# 16240                  World          WLD  2020-01-01
#
#        CO2 emissions (metric tons per capita)  Democracy index (EIU)  \
# 0                                    0.046057                    NaN
# 1                                    0.053589                    NaN
# 2                                    0.073721                    NaN
# 3                                    0.074161                    NaN
# 4                                    0.086174                    NaN
# ...                                       ...                    ...
# 16236                                     NaN                    NaN
# 16237                                     NaN                    NaN
# 16238                                     NaN                    NaN
# 16239                                     NaN                    NaN
# 16240                                     NaN                    NaN
#
#               Country Name_y  Compulsory education, duration (years)  \
# 0                Afghanistan                                     NaN
# 1                Afghanistan                                     NaN
# 2                Afghanistan                                     NaN
# 3                Afghanistan                                     NaN
# 4                Afghanistan                                     NaN
# ...                      ...                                     ...
# 16236                Vanuatu                                     NaN
# 16237  Virgin Islands (U.S.)                                     NaN
# 16238  Virgin Islands (U.S.)                                     NaN
# 16239                  World                                    10.0
# 16240                  World                                    10.0
#
#        GDP (current US$)  GDP per capita (current US$)  \
# 0           5.377778e+08                     59.773234
# 1           5.488889e+08                     59.860900
# 2           5.466667e+08                     58.458009
# 3           7.511112e+08                     78.706429
# 4           8.000000e+08                     82.095307
# ...                  ...                           ...
# 16236       8.547936e+08                   2782.984340
# 16237                NaN                           NaN
# 16238                NaN                           NaN
# 16239       8.743671e+13                  11394.861127
# 16240       8.457796e+13                  10909.287046
#
#        GDP per capita growth (annual %)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 16236                        -11.383066
# 16237                               NaN
# 16238                               NaN
# 16239                          1.480856
# 16240                         -4.395210
#
# [16241 rows x 10 columns]

# %%
# Dropping the attributes.
world_data_joined = world_data_joined.drop(columns=['Country Name_y'])
world_data_joined #Checking it worked.
# Out:
#               Country Name_x Country Code        Year  \
# 0                Afghanistan          AFG  1960-01-01
# 1                Afghanistan          AFG  1961-01-01
# 2                Afghanistan          AFG  1962-01-01
# 3                Afghanistan          AFG  1963-01-01
# 4                Afghanistan          AFG  1964-01-01
# ...                      ...          ...         ...
# 16236                Vanuatu          VUT  2020-01-01
# 16237  Virgin Islands (U.S.)          VIR  2019-01-01
# 16238  Virgin Islands (U.S.)          VIR  2020-01-01
# 16239                  World          WLD  2019-01-01
# 16240                  World          WLD  2020-01-01
#
#        CO2 emissions (metric tons per capita)  Democracy index (EIU)  \
# 0                                    0.046057                    NaN
# 1                                    0.053589                    NaN
# 2                                    0.073721                    NaN
# 3                                    0.074161                    NaN
# 4                                    0.086174                    NaN
# ...                                       ...                    ...
# 16236                                     NaN                    NaN
# 16237                                     NaN                    NaN
# 16238                                     NaN                    NaN
# 16239                                     NaN                    NaN
# 16240                                     NaN                    NaN
#
#        Compulsory education, duration (years)  GDP (current US$)  \
# 0                                         NaN       5.377778e+08
# 1                                         NaN       5.488889e+08
# 2                                         NaN       5.466667e+08
# 3                                         NaN       7.511112e+08
# 4                                         NaN       8.000000e+08
# ...                                       ...                ...
# 16236                                     NaN       8.547936e+08
# 16237                                     NaN                NaN
# 16238                                     NaN                NaN
# 16239                                    10.0       8.743671e+13
# 16240                                    10.0       8.457796e+13
#
#        GDP per capita (current US$)  GDP per capita growth (annual %)
# 0                         59.773234                               NaN
# 1                         59.860900                               NaN
# 2                         58.458009                               NaN
# 3                         78.706429                               NaN
# 4                         82.095307                               NaN
# ...                             ...                               ...
# 16236                   2782.984340                        -11.383066
# 16237                           NaN                               NaN
# 16238                           NaN                               NaN
# 16239                  11394.861127                          1.480856
# 16240                  10909.287046                         -4.395210
#
# [16241 rows x 9 columns]

# %% [markdown]
# ## Joins - World Data Joined + Country Meta Data
# This time we don't need any meta data on countries we haven't included so far. Regardless the country metadata is likely not to be larger than the world data. So a left join is sufficient.

# %%
world_data_complete = pd.merge(world_data_joined, country_metadata,  how='left', left_on=['Country Code'], right_on = ['Country Code'])
world_data_complete
# Out:
#               Country Name_x Country Code        Year  \
# 0                Afghanistan          AFG  1960-01-01
# 1                Afghanistan          AFG  1961-01-01
# 2                Afghanistan          AFG  1962-01-01
# 3                Afghanistan          AFG  1963-01-01
# 4                Afghanistan          AFG  1964-01-01
# ...                      ...          ...         ...
# 16236                Vanuatu          VUT  2020-01-01
# 16237  Virgin Islands (U.S.)          VIR  2019-01-01
# 16238  Virgin Islands (U.S.)          VIR  2020-01-01
# 16239                  World          WLD  2019-01-01
# 16240                  World          WLD  2020-01-01
#
#        CO2 emissions (metric tons per capita)  Democracy index (EIU)  \
# 0                                    0.046057                    NaN
# 1                                    0.053589                    NaN
# 2                                    0.073721                    NaN
# 3                                    0.074161                    NaN
# 4                                    0.086174                    NaN
# ...                                       ...                    ...
# 16236                                     NaN                    NaN
# 16237                                     NaN                    NaN
# 16238                                     NaN                    NaN
# 16239                                     NaN                    NaN
# 16240                                     NaN                    NaN
#
#        Compulsory education, duration (years)  GDP (current US$)  \
# 0                                         NaN       5.377778e+08
# 1                                         NaN       5.488889e+08
# 2                                         NaN       5.466667e+08
# 3                                         NaN       7.511112e+08
# 4                                         NaN       8.000000e+08
# ...                                       ...                ...
# 16236                                     NaN       8.547936e+08
# 16237                                     NaN                NaN
# 16238                                     NaN                NaN
# 16239                                    10.0       8.743671e+13
# 16240                                    10.0       8.457796e+13
#
#        GDP per capita (current US$)  GDP per capita growth (annual %)  \
# 0                         59.773234                               NaN
# 1                         59.860900                               NaN
# 2                         58.458009                               NaN
# 3                         78.706429                               NaN
# 4                         82.095307                               NaN
# ...                             ...                               ...
# 16236                   2782.984340                        -11.383066
# 16237                           NaN                               NaN
# 16238                           NaN                               NaN
# 16239                  11394.861127                          1.480856
# 16240                  10909.287046                         -4.395210
#
#                       Name      Capital City   Area Km2  Population  \
# 0              Afghanistan             Kabul  647,500.0  37,172,386
# 1              Afghanistan             Kabul  647,500.0  37,172,386
# 2              Afghanistan             Kabul  647,500.0  37,172,386
# 3              Afghanistan             Kabul  647,500.0  37,172,386
# 4              Afghanistan             Kabul  647,500.0  37,172,386
# ...                    ...               ...        ...         ...
# 16236              Vanuatu         Port Vila   12,200.0      292,68
# 16237  U.S. Virgin Islands  Charlotte Amalie      352.0     106,977
# 16238  U.S. Virgin Islands  Charlotte Amalie      352.0     106,977
# 16239                  NaN               NaN        NaN         NaN
# 16240                  NaN               NaN        NaN         NaN
#
#       Continent Code Continent Name
# 0                 AS           Asia
# 1                 AS           Asia
# 2                 AS           Asia
# 3                 AS           Asia
# 4                 AS           Asia
# ...              ...            ...
# 16236             OC        Oceania
# 16237             NA  North America
# 16238             NA  North America
# 16239            NaN            NaN
# 16240            NaN            NaN
#
# [16241 rows x 15 columns]

# %% [markdown]
# ## Table Cleaning

# %%
# Dropping the x from the col country code
world_data_complete = world_data_complete.rename(columns={"Country Name_x": "Country Name"})

# Dropping unneccessary columns.
world_data_complete = world_data_complete.drop(columns=['Name'])

# Checking it worked
world_data_complete
# Out:
#                 Country Name Country Code        Year  \
# 0                Afghanistan          AFG  1960-01-01
# 1                Afghanistan          AFG  1961-01-01
# 2                Afghanistan          AFG  1962-01-01
# 3                Afghanistan          AFG  1963-01-01
# 4                Afghanistan          AFG  1964-01-01
# ...                      ...          ...         ...
# 16236                Vanuatu          VUT  2020-01-01
# 16237  Virgin Islands (U.S.)          VIR  2019-01-01
# 16238  Virgin Islands (U.S.)          VIR  2020-01-01
# 16239                  World          WLD  2019-01-01
# 16240                  World          WLD  2020-01-01
#
#        CO2 emissions (metric tons per capita)  Democracy index (EIU)  \
# 0                                    0.046057                    NaN
# 1                                    0.053589                    NaN
# 2                                    0.073721                    NaN
# 3                                    0.074161                    NaN
# 4                                    0.086174                    NaN
# ...                                       ...                    ...
# 16236                                     NaN                    NaN
# 16237                                     NaN                    NaN
# 16238                                     NaN                    NaN
# 16239                                     NaN                    NaN
# 16240                                     NaN                    NaN
#
#        Compulsory education, duration (years)  GDP (current US$)  \
# 0                                         NaN       5.377778e+08
# 1                                         NaN       5.488889e+08
# 2                                         NaN       5.466667e+08
# 3                                         NaN       7.511112e+08
# 4                                         NaN       8.000000e+08
# ...                                       ...                ...
# 16236                                     NaN       8.547936e+08
# 16237                                     NaN                NaN
# 16238                                     NaN                NaN
# 16239                                    10.0       8.743671e+13
# 16240                                    10.0       8.457796e+13
#
#        GDP per capita (current US$)  GDP per capita growth (annual %)  \
# 0                         59.773234                               NaN
# 1                         59.860900                               NaN
# 2                         58.458009                               NaN
# 3                         78.706429                               NaN
# 4                         82.095307                               NaN
# ...                             ...                               ...
# 16236                   2782.984340                        -11.383066
# 16237                           NaN                               NaN
# 16238                           NaN                               NaN
# 16239                  11394.861127                          1.480856
# 16240                  10909.287046                         -4.395210
#
#            Capital City   Area Km2  Population Continent Code Continent Name
# 0                 Kabul  647,500.0  37,172,386             AS           Asia
# 1                 Kabul  647,500.0  37,172,386             AS           Asia
# 2                 Kabul  647,500.0  37,172,386             AS           Asia
# 3                 Kabul  647,500.0  37,172,386             AS           Asia
# 4                 Kabul  647,500.0  37,172,386             AS           Asia
# ...                 ...        ...         ...            ...            ...
# 16236         Port Vila   12,200.0      292,68             OC        Oceania
# 16237  Charlotte Amalie      352.0     106,977             NA  North America
# 16238  Charlotte Amalie      352.0     106,977             NA  North America
# 16239               NaN        NaN         NaN            NaN            NaN
# 16240               NaN        NaN         NaN            NaN            NaN
#
# [16241 rows x 14 columns]

# %% [markdown]
# ## Understanding Countries
# There are a few countries in the table, it seems, that are not real countries.

# %%
# This will be used to store the unique countries. Will be used in World_Cities file.
countries = world_data_complete['Country Name'].unique()

# %%
len(countries) # no of unique countries we have so far.
# Out:
# 282

# %%
countries
# Out:
# array(['Afghanistan', 'Africa Eastern and Southern',
#        'Africa Western and Central', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Antigua and Barbuda',
#        'Arab World', 'Argentina', 'Armenia', 'Aruba', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda',
#        'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'British Virgin Islands', 'Brunei Darussalam',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia',
#        'Cameroon', 'Canada', 'Caribbean small states', 'Cayman Islands',
#        'Central African Republic', 'Central Europe and the Baltics',
#        'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic',
#        'Early-demographic dividend', 'East Asia & Pacific',
#        'East Asia & Pacific (IDA & IBRD countries)',
#        'East Asia & Pacific (excluding high income)', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (IDA & IBRD countries)',
#        'Europe & Central Asia (excluding high income)', 'European Union',
#        'Faroe Islands', 'Fiji', 'Finland',
#        'Fragile and conflict affected situations', 'France',
#        'French Polynesia', 'Gabon', 'Gambia, The', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'Honduras', 'Hong Kong SAR, China', 'Hungary', 'IBRD only',
#        'IDA & IBRD total', 'IDA blend', 'IDA only', 'IDA total',
#        'Iceland', 'India', 'Indonesia', 'Iran, Islamic Rep.', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Kosovo', 'Kuwait',
#        'Kyrgyz Republic', 'Lao PDR', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)', 'Latvia',
#        'Least developed countries: UN classification', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Luxembourg', 'Macao SAR, China', 'Madagascar', 'Malawi',
#        'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands',
#        'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Fed. Sts.',
#        'Middle East & North Africa',
#        'Middle East & North Africa (IDA & IBRD countries)',
#        'Middle East & North Africa (excluding high income)',
#        'Middle income', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro',
#        'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
#        'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua',
#        'Niger', 'Nigeria', 'North America', 'North Macedonia',
#        'Northern Mariana Islands', 'Norway', 'OECD members', 'Oman',
#        'Other small states', 'Pacific island small states', 'Pakistan',
#        'Palau', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Post-demographic dividend',
#        'Pre-demographic dividend', 'Puerto Rico', 'Qatar', 'Romania',
#        'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia',
#        'Small states', 'Solomon Islands', 'Somalia', 'South Africa',
#        'South Asia', 'South Asia (IDA & IBRD)', 'South Sudan', 'Spain',
#        'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia',
#        'St. Martin (French part)', 'St. Vincent and the Grenadines',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (IDA & IBRD countries)',
#        'Sub-Saharan Africa (excluding high income)', 'Sudan', 'Suriname',
#        'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Tajikistan',
#        'Tanzania', 'Thailand', 'Timor-Leste', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela, RB', 'Vietnam', 'Virgin Islands (U.S.)',
#        'West Bank and Gaza', 'World', 'Yemen, Rep.', 'Zambia', 'Zimbabwe',
#        'Cape Verde', 'Egypt', 'Gambia', 'Hong Kong, China', 'Iran', 'Lao',
#        'Macedonia, FYR', 'North Korea', 'Palestine', 'Russia',
#        'South Korea', 'Swaziland', 'Syria', 'Taiwan', 'Venezuela',
#        'Yemen', 'Not classified'], dtype=object)

# %% [markdown]
# We know that the country data in the country meta data is correct. So let's view only the additional 'countries'.

# %%
countries_meta_names = country_metadata['Name'].unique()

# %%
additional = len(countries) - len(countries_meta_names)

# %%
additional # no of additional countries
# Out:
# 32

# %%
additional_countries = [x for x in countries if x not in countries_meta_names]

# %%
additional_countries # This didn't work as the name spelling is different. Should be done on code.
# Out:
# ['Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Arab World',
#  'Bahamas, The',
#  'Brunei Darussalam',
#  'Caribbean small states',
#  'Central Europe and the Baltics',
#  'Channel Islands',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  "Cote d'Ivoire",
#  'Curacao',
#  'Czech Republic',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'East Asia & Pacific (excluding high income)',
#  'Egypt, Arab Rep.',
#  'Euro area',
#  'Europe & Central Asia',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'Europe & Central Asia (excluding high income)',
#  'European Union',
#  'Fragile and conflict affected situations',
#  'Gambia, The',
#  'Heavily indebted poor countries (HIPC)',
#  'High income',
#  'Hong Kong SAR, China',
#  'IBRD only',
#  'IDA & IBRD total',
#  'IDA blend',
#  'IDA only',
#  'IDA total',
#  'Iran, Islamic Rep.',
#  "Korea, Dem. People's Rep.",
#  'Korea, Rep.',
#  'Kyrgyz Republic',
#  'Lao PDR',
#  'Late-demographic dividend',
#  'Latin America & Caribbean',
#  'Latin America & Caribbean (excluding high income)',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Least developed countries: UN classification',
#  'Low & middle income',
#  'Low income',
#  'Lower middle income',
#  'Macao SAR, China',
#  'Micronesia, Fed. Sts.',
#  'Middle East & North Africa',
#  'Middle East & North Africa (IDA & IBRD countries)',
#  'Middle East & North Africa (excluding high income)',
#  'Middle income',
#  'North America',
#  'OECD members',
#  'Other small states',
#  'Pacific island small states',
#  'Post-demographic dividend',
#  'Pre-demographic dividend',
#  'Russian Federation',
#  'Sao Tome and Principe',
#  'Sint Maarten (Dutch part)',
#  'Slovak Republic',
#  'Small states',
#  'South Asia',
#  'South Asia (IDA & IBRD)',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Martin (French part)',
#  'St. Vincent and the Grenadines',
#  'Sub-Saharan Africa',
#  'Sub-Saharan Africa (IDA & IBRD countries)',
#  'Sub-Saharan Africa (excluding high income)',
#  'Syrian Arab Republic',
#  'Upper middle income',
#  'Venezuela, RB',
#  'Virgin Islands (U.S.)',
#  'West Bank and Gaza',
#  'World',
#  'Yemen, Rep.',
#  'Cape Verde',
#  'Gambia',
#  'Hong Kong, China',
#  'Lao',
#  'Macedonia, FYR',
#  'Swaziland',
#  'Not classified']

# %% [markdown]
# There are a lot of mismatched countries and 'non' countries. For example "Upper middle income" is not a country. However there are also countries named here that should be included but have spelling variations. For example Côte d'Ivoire is also known as the Ivory Coast.
#
# Therefore it is best to run this match again on the basis of their 'country code'.

# %%
countries_meta_code = country_metadata['Country Code'].unique()
countries_code = world_data_complete['Country Code'].unique()

# %%
additional_countries_code = [x for x in countries_code if x not in countries_meta_code]

# %%
print('Mismatch Countries By Code: ', len(additional_countries_code))
print('Mismatch Countries By Name: ', len(additional_countries))
# Out:
# Mismatch Countries By Code:  50
# Mismatch Countries By Name:  86

# %% [markdown]
# We have now eliminated a difference of 36 countries. These 36 countries should really be checked through to verify the correct spelling.. but for now we can look at the 50 mismatched countries.

# %%
mismatch_data = world_data_complete[world_data_complete['Country Code'].isin(additional_countries_code)]

# %%
mismatch_data
# Out:
#                                      Country Name Country Code        Year  \
# 59                    Africa Eastern and Southern          AFE  1960-01-01
# 60                    Africa Eastern and Southern          AFE  1961-01-01
# 61                    Africa Eastern and Southern          AFE  1962-01-01
# 62                    Africa Eastern and Southern          AFE  1963-01-01
# 63                    Africa Eastern and Southern          AFE  1964-01-01
# ...                                           ...          ...         ...
# 16225  Sub-Saharan Africa (excluding high income)          SSA  2020-01-01
# 16233                         Upper middle income          UMC  2019-01-01
# 16234                         Upper middle income          UMC  2020-01-01
# 16239                                       World          WLD  2019-01-01
# 16240                                       World          WLD  2020-01-01
#
#        CO2 emissions (metric tons per capita)  Democracy index (EIU)  \
# 59                                   0.906060                    NaN
# 60                                   0.922474                    NaN
# 61                                   0.930816                    NaN
# 62                                   0.940570                    NaN
# 63                                   0.996033                    NaN
# ...                                       ...                    ...
# 16225                                     NaN                    NaN
# 16233                                     NaN                    NaN
# 16234                                     NaN                    NaN
# 16239                                     NaN                    NaN
# 16240                                     NaN                    NaN
#
#        Compulsory education, duration (years)  GDP (current US$)  \
# 59                                        NaN       1.934248e+10
# 60                                        NaN       1.975349e+10
# 61                                        NaN       2.152662e+10
# 62                                        NaN       2.577236e+10
# 63                                        NaN       2.356323e+10
# ...                                       ...                ...
# 16225                                     8.0       1.686475e+12
# 16233                                    10.0       2.397975e+13
# 16234                                    10.0       2.310488e+13
# 16239                                    10.0       8.743671e+13
# 16240                                    10.0       8.457796e+13
#
#        GDP per capita (current US$)  GDP per capita growth (annual %)  \
# 59                       147.836769                               NaN
# 60                       147.238537                               NaN
# 61                       156.426780                               NaN
# 62                       182.521139                               NaN
# 63                       162.594548                               NaN
# ...                             ...                               ...
# 16225                   1484.640636                         -4.517211
# 16233                   9589.037874                          3.523367
# 16234                   9191.680733                         -1.160616
# 16239                  11394.861127                          1.480856
# 16240                  10909.287046                         -4.395210
#
#       Capital City Area Km2 Population Continent Code Continent Name
# 59             NaN      NaN        NaN            NaN            NaN
# 60             NaN      NaN        NaN            NaN            NaN
# 61             NaN      NaN        NaN            NaN            NaN
# 62             NaN      NaN        NaN            NaN            NaN
# 63             NaN      NaN        NaN            NaN            NaN
# ...            ...      ...        ...            ...            ...
# 16225          NaN      NaN        NaN            NaN            NaN
# 16233          NaN      NaN        NaN            NaN            NaN
# 16234          NaN      NaN        NaN            NaN            NaN
# 16239          NaN      NaN        NaN            NaN            NaN
# 16240          NaN      NaN        NaN            NaN            NaN
#
# [3050 rows x 14 columns]

# %%
mismatch_unique = mismatch_data['Country Name'].unique()

# %% [markdown]
# This view is much easier to sort through

# %%
mismatch_unique
# Out:
# array(['Africa Eastern and Southern', 'Africa Western and Central',
#        'Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Channel Islands',
#        'Early-demographic dividend', 'East Asia & Pacific',
#        'East Asia & Pacific (IDA & IBRD countries)',
#        'East Asia & Pacific (excluding high income)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (IDA & IBRD countries)',
#        'Europe & Central Asia (excluding high income)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Middle East & North Africa',
#        'Middle East & North Africa (IDA & IBRD countries)',
#        'Middle East & North Africa (excluding high income)',
#        'Middle income', 'North America', 'OECD members',
#        'Other small states', 'Pacific island small states',
#        'Post-demographic dividend', 'Pre-demographic dividend',
#        'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (IDA & IBRD countries)',
#        'Sub-Saharan Africa (excluding high income)',
#        'Upper middle income', 'World', 'Not classified'], dtype=object)

# %% [markdown]
# None of the above are "States", although there are groups of states with clear definitions. Such as European Union or OECD members. From the preview of the mismatch_data df, we can see the data on these groups is mainly CO2 or GDP. We can now remove these rows from the main df.

# %%
# Checking no rows beforehand
pre_drop_rows = len(world_data_complete.index)
pre_drop_rows
# Out:
# 16241

# %%
world_data_complete = world_data_complete[~world_data_complete['Country Code'].isin(additional_countries_code)]

# %%
world_data_complete
# Out:
#                 Country Name Country Code        Year  \
# 0                Afghanistan          AFG  1960-01-01
# 1                Afghanistan          AFG  1961-01-01
# 2                Afghanistan          AFG  1962-01-01
# 3                Afghanistan          AFG  1963-01-01
# 4                Afghanistan          AFG  1964-01-01
# ...                      ...          ...         ...
# 16232                Ukraine          UKR  2020-01-01
# 16235                Vanuatu          VUT  2019-01-01
# 16236                Vanuatu          VUT  2020-01-01
# 16237  Virgin Islands (U.S.)          VIR  2019-01-01
# 16238  Virgin Islands (U.S.)          VIR  2020-01-01
#
#        CO2 emissions (metric tons per capita)  Democracy index (EIU)  \
# 0                                    0.046057                    NaN
# 1                                    0.053589                    NaN
# 2                                    0.073721                    NaN
# 3                                    0.074161                    NaN
# 4                                    0.086174                    NaN
# ...                                       ...                    ...
# 16232                                     NaN                    NaN
# 16235                                     NaN                    NaN
# 16236                                     NaN                    NaN
# 16237                                     NaN                    NaN
# 16238                                     NaN                    NaN
#
#        Compulsory education, duration (years)  GDP (current US$)  \
# 0                                         NaN       5.377778e+08
# 1                                         NaN       5.488889e+08
# 2                                         NaN       5.466667e+08
# 3                                         NaN       7.511112e+08
# 4                                         NaN       8.000000e+08
# ...                                       ...                ...
# 16232                                    11.0       1.555820e+11
# 16235                                     NaN       9.303380e+08
# 16236                                     NaN       8.547936e+08
# 16237                                     NaN                NaN
# 16238                                     NaN                NaN
#
#        GDP per capita (current US$)  GDP per capita growth (annual %)  \
# 0                         59.773234                               NaN
# 1                         59.860900                               NaN
# 2                         58.458009                               NaN
# 3                         78.706429                               NaN
# 4                         82.095307                               NaN
# ...                             ...                               ...
# 16232                   3726.927149                         -3.370977
# 16235                   3102.346790                          0.782854
# 16236                   2782.984340                        -11.383066
# 16237                           NaN                               NaN
# 16238                           NaN                               NaN
#
#            Capital City   Area Km2  Population Continent Code Continent Name
# 0                 Kabul  647,500.0  37,172,386             AS           Asia
# 1                 Kabul  647,500.0  37,172,386             AS           Asia
# 2                 Kabul  647,500.0  37,172,386             AS           Asia
# 3                 Kabul  647,500.0  37,172,386             AS           Asia
# 4                 Kabul  647,500.0  37,172,386             AS           Asia
# ...                 ...        ...         ...            ...            ...
# 16232              Kyiv  603,700.0  44,622,516             EU         Europe
# 16235         Port Vila   12,200.0      292,68             OC        Oceania
# 16236         Port Vila   12,200.0      292,68             OC        Oceania
# 16237  Charlotte Amalie      352.0     106,977             NA  North America
# 16238  Charlotte Amalie      352.0     106,977             NA  North America
#
# [13191 rows x 14 columns]

# %%
# Checking rows afterwards. Should be 3050 less rows.

def check_drop(pre_drop_rows, world_data_complete, mismatch_data):
    '''
        Takes pre_drop_rows, (len(world_data_complete.index)), from before the drop. The dataframe and the rows we are dropping.
        Returns an error if the drop did not work.
    
    '''
    rows_to_drop = len(mismatch_data)
    post_drop_rows = len(world_data_complete.index)
    dropped_rows = pre_drop_rows - post_drop_rows
    e = 'drop did not work as expected'
    p = 'drop worked successfully'
    return print(p) if dropped_rows == rows_to_drop else print(e)

check_drop(pre_drop_rows, world_data_complete, mismatch_data)
# Out:
# drop worked successfully

# %% [markdown]
# Now back to those 36 countries that were in the mismatch names, but not in mismatch code. These are maybe spelling issues.
# To calculate this, the countries will be in 'additional_countries' but not in 'additional_countries_code'. As the countries in the 'additional_countries_code' are no longer there, the filtering the dataframe for matches in 'additional_countries' should show all.

# %%
spelling_variations_df = world_data_complete[world_data_complete['Country Name'].isin(additional_countries)]

# %%
spelling_variations = spelling_variations_df['Country Name'].unique()

# %%
len(spelling_variations)
# Out:
# 36

# %%
spelling_variations
# Out:
# array(['Bahamas, The', 'Brunei Darussalam', 'Congo, Dem. Rep.',
#        'Congo, Rep.', "Cote d'Ivoire", 'Curacao', 'Czech Republic',
#        'Egypt, Arab Rep.', 'Gambia, The', 'Hong Kong SAR, China',
#        'Iran, Islamic Rep.', "Korea, Dem. People's Rep.", 'Korea, Rep.',
#        'Kyrgyz Republic', 'Lao PDR', 'Macao SAR, China',
#        'Micronesia, Fed. Sts.', 'Russian Federation',
#        'Sao Tome and Principe', 'Sint Maarten (Dutch part)',
#        'Slovak Republic', 'St. Kitts and Nevis', 'St. Lucia',
#        'St. Martin (French part)', 'St. Vincent and the Grenadines',
#        'Syrian Arab Republic', 'Venezuela, RB', 'Virgin Islands (U.S.)',
#        'West Bank and Gaza', 'Yemen, Rep.', 'Cape Verde', 'Gambia',
#        'Hong Kong, China', 'Lao', 'Macedonia, FYR', 'Swaziland'],
#       dtype=object)

# %% [markdown]
# ## Export CSV

# %%
world_data_complete.to_csv('world_data_complete.csv')
